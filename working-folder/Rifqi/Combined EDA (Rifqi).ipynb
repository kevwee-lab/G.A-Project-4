# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
trainzq = pd.read_csv('../../data/train_eng.csv', parse_dates=['date'])
trainkev = pd.read_csv('../../data/train_eng_kev.csv', parse_dates=['date'])
weather = pd.read_csv('../../data/weather_eng.csv', parse_dates=['date'])

# %%
trainzq.head()
# Out:
#         date                 species  totalmosquitos  wnvpresent  trap  \
# 0 2007-05-29           CULEX PIPIENS               1           0  T096
# 1 2007-05-29  CULEX PIPIENS/RESTUANS               1           0  T086
# 2 2007-05-29  CULEX PIPIENS/RESTUANS               1           0  T048
# 3 2007-05-29  CULEX PIPIENS/RESTUANS               1           0  T129
# 4 2007-05-29  CULEX PIPIENS/RESTUANS               1           0  T050
#
#     latitude  longitude
# 0  41.731922 -87.677512
# 1  41.688324 -87.676709
# 2  41.867108 -87.654224
# 3  41.891126 -87.611560
# 4  41.919343 -87.694259

# %%
trainkev.head()
# Out:
#    Unnamed: 0       date                 species  trap   latitude  longitude  \
# 0           0 2007-05-29           CULEX PIPIENS  T096  41.731922 -87.677512
# 1           1 2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 2           2 2007-05-29  CULEX PIPIENS/RESTUANS  T015  41.974089 -87.824812
# 3           3 2007-05-29  CULEX PIPIENS/RESTUANS  T048  41.867108 -87.654224
# 4           4 2007-05-29  CULEX PIPIENS/RESTUANS  T050  41.919343 -87.694259
#
#    year  month  nummosquitos  wnvpresent  species_ord
# 0  2007      5             1           0          2.0
# 1  2007      5             1           0          2.0
# 2  2007      5             1           0          2.0
# 3  2007      5             1           0          2.0
# 4  2007      5             1           0          2.0

# %%
trainzq['species_ord'] = trainkev['species_ord']

# %%
trainzq.head()
# Out:
#         date                 species  totalmosquitos  wnvpresent  trap  \
# 0 2007-05-29           CULEX PIPIENS               1           0  T096
# 1 2007-05-29  CULEX PIPIENS/RESTUANS               1           0  T086
# 2 2007-05-29  CULEX PIPIENS/RESTUANS               1           0  T048
# 3 2007-05-29  CULEX PIPIENS/RESTUANS               1           0  T129
# 4 2007-05-29  CULEX PIPIENS/RESTUANS               1           0  T050
#
#     latitude  longitude  species_ord
# 0  41.731922 -87.677512          2.0
# 1  41.688324 -87.676709          2.0
# 2  41.867108 -87.654224          2.0
# 3  41.891126 -87.611560          2.0
# 4  41.919343 -87.694259          2.0

# %%
weather.head()
# Out:
#    Unnamed: 0       date  tmax  tmin  tavg  depart  dewpoint  wetbulb  heat  \
# 0           0 2007-05-01    83    51    67      14        51       56     0
# 1           1 2007-05-02    59    42    51      -2        42       47    13
# 2           2 2007-05-03    66    47    57       3        40       49     8
# 3           3 2007-05-04    72    50    61       7        41       50     4
# 4           4 2007-05-05    66    53    60       5        38       49     5
#
#    cool  ...  tavg_lag28  rel_humid_lag5  rel_humid_lag14  rel_humid_lag28  \
# 0     2  ...         NaN             NaN              NaN              NaN
# 1     0  ...         NaN             NaN              NaN              NaN
# 2     0  ...         NaN             NaN              NaN              NaN
# 3     0  ...         NaN             NaN              NaN              NaN
# 4     0  ...         NaN       39.634503              NaN              NaN
#
#    avgspeed_lag5  avgspeed_lag14  avgspeed_lag28  preciptotal_lag5  \
# 0            NaN             NaN             NaN               NaN
# 1            NaN             NaN             NaN               NaN
# 2            NaN             NaN             NaN               NaN
# 3            NaN             NaN             NaN               NaN
# 4          11.54             NaN             NaN             0.002
#
#    preciptotal_lag14  preciptotal_lag28
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
#
# [5 rows x 46 columns]

# %%
comb = pd.merge(trainzq, weather, on='date').drop(columns='Unnamed: 0')

# %%
comb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8475 entries, 0 to 8474
# Data columns (total 52 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               8475 non-null   datetime64[ns]
#  1   species            8475 non-null   object
#  2   totalmosquitos     8475 non-null   int64
#  3   wnvpresent         8475 non-null   int64
#  4   trap               8475 non-null   object
#  5   latitude           8475 non-null   float64
#  6   longitude          8475 non-null   float64
#  7   species_ord        8475 non-null   float64
#  8   tmax               8475 non-null   int64
#  9   tmin               8475 non-null   int64
#  10  tavg               8475 non-null   int64
#  11  depart             8475 non-null   int64
#  12  dewpoint           8475 non-null   int64
#  13  wetbulb            8475 non-null   int64
#  14  heat               8475 non-null   int64
#  15  cool               8475 non-null   int64
#  16  sunrise            8475 non-null   int64
#  17  sunset             8475 non-null   int64
#  18  preciptotal        8475 non-null   float64
#  19  stnpressure        8475 non-null   float64
#  20  sealevel           8475 non-null   float64
#  21  resultspeed        8475 non-null   float64
#  22  resultdir          8475 non-null   int64
#  23  avgspeed           8475 non-null   float64
#  24  BC                 8475 non-null   int64
#  25  HZ                 8475 non-null   int64
#  26  DZ                 8475 non-null   int64
#  27  VC                 8475 non-null   int64
#  28  SQ                 8475 non-null   int64
#  29  TS                 8475 non-null   int64
#  30  RA                 8475 non-null   int64
#  31  GR                 8475 non-null   int64
#  32  MI                 8475 non-null   int64
#  33  BR                 8475 non-null   int64
#  34  FU                 8475 non-null   int64
#  35  FG+                8475 non-null   int64
#  36  FG                 8475 non-null   int64
#  37  SN                 8475 non-null   int64
#  38  rel_humid          8475 non-null   float64
#  39  tavg_change        8475 non-null   float64
#  40  tavg_lag5          8475 non-null   float64
#  41  tavg_lag14         8475 non-null   float64
#  42  tavg_lag28         8475 non-null   float64
#  43  rel_humid_lag5     8475 non-null   float64
#  44  rel_humid_lag14    8475 non-null   float64
#  45  rel_humid_lag28    8475 non-null   float64
#  46  avgspeed_lag5      8475 non-null   float64
#  47  avgspeed_lag14     8475 non-null   float64
#  48  avgspeed_lag28     8475 non-null   float64
#  49  preciptotal_lag5   8475 non-null   float64
#  50  preciptotal_lag14  8475 non-null   float64
#  51  preciptotal_lag28  8475 non-null   float64
# dtypes: datetime64[ns](1), float64(22), int64(27), object(2)
# memory usage: 3.4+ MB

# %% [markdown]
# ## Total Mosquitos

# %%
# Top 10 features correlated to wnvpresent
comb.corr()[['wnvpresent']].abs().sort_values('wnvpresent',ascending=False)[1:11]
# Out:
#                  wnvpresent
# totalmosquitos     0.233532
# avgspeed_lag28     0.138465
# rel_humid_lag14    0.136085
# tavg_lag28         0.131077
# rel_humid_lag28    0.126917
# rel_humid_lag5     0.111116
# species_ord        0.108576
# avgspeed_lag14     0.102773
# tavg_lag14         0.100259
# sunrise            0.097634

# %% [markdown]
# As seen above, the features in our dataset generally have low correlation to `wnvpresent`. The top 10 consists mostly of features that we engineered earlier on, while the strongest feature turns out to be `totalmosquitos`, with a Pearson correlation score of 0.23 with our target. However, upon further study of our dataset, the use of this feature in our final model might be quite limited.
#
# The test dataset does not contain the `NumMosquitos` column that we used to create the `totalmosquitos` feature in our train data. We explored using the structure of the data (total number of rows for each unique date-species-trap) to estimate the number of mosquitos in the test set, since the observations were capped at 50 mosquitos per row. However, although it may have worked for this particular dataset, we decided that it would not be useful for our model outside of this particular use case.

# %%
# Top 10 features correlated to totalmosquitos
comb.corr()[['totalmosquitos']].abs().sort_values('totalmosquitos',ascending=False)[1:11]
# Out:
#              totalmosquitos
# wnvpresent         0.233532
# tmin               0.068040
# tavg_lag5          0.066488
# species_ord        0.066198
# cool               0.065672
# tavg               0.065043
# wetbulb            0.059867
# latitude           0.058984
# tavg_lag14         0.057675
# tmax               0.057313

# %% [markdown]
# Additionally, as seen above, all other independent features had very low correlation to `totalmosquitos`, and predicting the value of `totalmosquitos` using a secondary regression model would just add another layer of randomness that may not be useful to improving our model. Ultimately, due to the reasons above, we decided to drop the feature from our final model.

# %%
comb.drop(columns='totalmosquitos', inplace=True)
